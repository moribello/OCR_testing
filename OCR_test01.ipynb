# %%
from PIL import Image
import numpy as np
import pytesseract
import os
import matplotlib.pyplot as plt
import cv2

# %%
from IPython.display import Image
Image(filename='Ferndale_CA_War_Memorial_Plaque.jpg')

# %%
img = cv2.imread('Ferndale_CA_War_Memorial_Plaque.jpg',0)
retval, img_adj = cv2.threshold(img, 150, 255, cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY_INV)


def imgSweep(img, low, high):
     
    for thresh in range(low,high, 10):
        plt.figure(figsize=(14, 60))
        retval, img_adj= cv2.threshold(img, thresh, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV)
#         plt.title(i)
#         plt.imshow(img_adj, cmap="gray")
        print("="*80)
        print("threshold is: ", thresh)
        print(pytesseract.image_to_string(img_adj))
        print("="*80)
imgSweep(img, 100, 250)
# Out:
# ...
# threshold is:  50
# eA - -~e -
#
# - . SAYA Aa
#
#
#
#
#
#
#
# " “~ ~ - oe . - - ~
#
# wiv ty Sn De Re TS ee
#
#
#
#
#
# cs Ae
#
# . Oye AR eee CAA AL eS ee oe
#
#
#
# DP pres Set ee seamen we ee
# PSS AAA ee A
#
#
#
# Atte pee A NAS OA Se eee
#
#
#
# DS yb o ee a wu a LALA .
#
# / - - a ~ :
# DS sapere Fa Addo Ae ee te a Lose
#
# PvtAB SD Ae
#
# we LAL
#
# SA AE te 7
#
#
#
#
#
#
#
# ASIII Noe ol
#
#
#
# mye oe . .
# IPB Le Ae
#
#
#
#
#
# MD NR AC -
#
#
#
# Fda ase saa
#
#
#
# AAA ee”
# A oe
# SUL a, en mS
#
#
#
#
#
#
# fae de
# ...
# threshold is:  60
# AAs Os ot
# A ee te
#
# abated Jee Sei FS
#
# fii nine
# ...
# threshold is:  70
#
# ...
# threshold is:  80
# Se
#
# Acidic
# ...
# threshold is:  90
# . paid : ee
# c eda isd eee
#
#
#
# Mee ee)
#
#
#
# Cs er
# ...
# threshold is:  100
# ae ole BROTHERS, Ered & ase :
# caus in De
#
#
#
#
#
# einai Soe
# me Ae celica
# a ee Boots... ;
#
# ; ;
# oreld Cs i
#
# eat WAR ; f
# Resid i Co Jr
#
# anyon WAR ~
#
# eu ee
# it Ae ea ee
# bia ae Ph Jacobsen: -
#
#
#
#
#
#
# ...

# %%
cv2.imshow('threshold',img_adj)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
print(pytesseract.image_to_string(img_adj))
# Out:
# 2X = A i410), 0 el ama
#
#
#
# SONS, BROTHERS, HUSBANDS & FATHERS
# OF THE FERNDALE AREA
# WHO GAVE THEIR LAST FULL MEASURE OF DEVOTION
# FOR THE GLORY OF GOD AND COUNTRY
#
# fo] thom 7\ ae
#
# Jerrold J, Aggeler
# Joseph Caretti
# William P. Dilfon
# William H. Jensen
# Albert Joppas
#
# XS ae Ol t-te
#
# Arthur N. Rasmussen
# Otto P. Schoenemann
# Horold H. Tyrell
#
# KOREAN WAR
#
# Chester F. Reas, Jr.
#
# VIETNAM WAR
# Howard M. Gifford
# David E. Hubner
# Tie it J. dor borer
# L,le “2 .terts
#
# C' on eataae,
#
# Vee) tee N aa
#
# Richard L. Adoms, Jr.
# Gerald W. Beauchamp
# Morris A. Boots
#
# John B. Campbell
# Aldo DeCarli
#
# Takei ee hd hg
#
# Tony L. Gomes
# Matthies P. Hansen
# Leroy Lampella
#
# Frank P. Lewis
#
# Stuart R. Macklin
# Donald E. Pedrazzini
# Albert A. Pullen, Jr.
# Kenneth A. Rasmussen
# John D. Robertson, Ir.
# Robert WH. Smith
# Merritt Tompkins
# George E. Wilsen
# SAliit- te Mere a AoXetoltol-1.4
#
# DEDICATED NOVEMBER 117, 1993
#
# AMERICAN LEGION
# ...
